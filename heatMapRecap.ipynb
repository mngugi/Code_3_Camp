# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

dt = np.random.rand(10, 12)
sns.heatmap(dt, cmap='Oranges')

plt.show()

# %% [markdown]
# ### Explanation
# 1. Import Required Libraries:
#
# - seaborn for heatmap visualization.
# - matplotlib.pyplot for displaying the heatmap.
# - numpy for generating a random dataset.
#
# 2. Generate Random Data:
#
# - np.random.rand(10, 12) creates a 10×12 matrix with random values between 0 and 1.
#
# 3. Create a Heatmap:
#
# - sns.heatmap(dt, cmap='Oranges') generates the heatmap.
# - The cmap='Oranges' argument applies an orange color gradient.
#
# 4. Display the Heatmap:
#
# - plt.show() renders the visualization.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate Random Data (10x12 Matrix)
np.random.seed(42)  # For reproducibility
dt = np.random.rand(10, 12)

# Set figure size
plt.figure(figsize=(10, 6))

# Create Heatmap with Customizations
sns.heatmap(
    dt, 
    cmap='coolwarm',  # Color gradient (from cool to warm)
    annot=True,  # Show values inside the heatmap
    fmt=".2f",  # Format numbers to 2 decimal places
    linewidths=0.5,  # Add grid lines between cells
    linecolor='black',  # Grid line color
    cbar_kws={"shrink": 0.8, "aspect": 40}  # Adjust color bar size
)

# Add Labels and Title
plt.xlabel("Columns", fontsize=12)
plt.ylabel("Rows", fontsize=12)
plt.title("Enhanced Heatmap with Seaborn", fontsize=14, fontweight="bold")

# Display the Heatmap
plt.show()

# %% [markdown]
# 🔹 Explanation of Enhancements
# - Color Customization (cmap='coolwarm')
#
# Uses "coolwarm" to differentiate high & low values.
# - You can try 'viridis', 'Blues', 'Greens', or 'magma'.
# - Annotations (annot=True, fmt=".2f")
#
# Displays values inside cells.
# - Formats numbers to 2 decimal places.
# - Grid Styling (linewidths=0.5, linecolor='black')
#
# Adds black grid lines to separate values.
# - Color Bar (cbar_kws={"shrink": 0.8, "aspect": 40})
#
# Shrinks the color bar for better readability.
# - Labels & Titles
#
# Title: "Enhanced Heatmap with Seaborn"
# - X-axis & Y-axis Labels: "Columns" & "Rows"
