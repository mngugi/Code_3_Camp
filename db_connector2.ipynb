# %%
import mysql.connector
from sqlalchemy import create_engine
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# database user connection details
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    .
    password="$$$$$*s****",
    database="sys"
)
'''
cursor = connection.cursor()

cursor.execute("SELECT * FROM x$user_summary;")
rows = cursor.fetchall()
for row in rows:
    print(row)
'''
df = pd.read_sql("SELECT * FROM x$user_summary", con=connection)

# Display the DataFrame
df.head()  # Display the first few rows of the DataFrame

#cursor.close()
#connection.close()
# Out:
#               user  statements  statement_latency  statement_avg_latency  \
# 0             root       423.0       1.790711e+12           4.233359e+09
# 1       background         0.0       0.000000e+00           0.000000e+00
# 2  event_scheduler         0.0       0.000000e+00           0.000000e+00
#
#    table_scans  file_ios  file_io_latency  current_connections  \
# 0         42.0     167.0     2.712669e+11                  5.0
# 1          0.0    2888.0     4.616203e+12                 36.0
# 2          0.0       0.0     0.000000e+00                  1.0
#
#    total_connections  unique_hosts  current_memory  total_memory_allocated
# 0               26.0             1      10632041.0            1.051565e+09
# 1               48.0             0       2181374.0            6.772057e+07
# 2                1.0             1         16665.0            1.666500e+04
