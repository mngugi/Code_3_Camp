# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data-visualisation-for-beginners/Electricity Connections.csv

# %%
# load data
dt = pd.read_csv("/kaggle/input/data-visualisation-for-beginners/Electricity Connections.csv")
dt.head()
# Out:
#    Districts  Domestic Connections  Industrial Connections  \
# 0   ADILABAD                151936                    1074
# 1  BHADRADRI                272987                    1396
# 2  HYDERABAD               1469633                   13041
# 3   JAGTIAL                 267097                    2132
# 4   JANGAON                 148566                    1536
#
#    Agriculture Connections  Commercial Connections  Other Connections
# 0                    17948                   14641               3302
# 1                    29951                   25990               5911
# 2                       86                  324781              18987
# 3                   113165                   23109               6499
# 4                    80002                   11366               4432

# %%
import matplotlib.pyplot as plt
dt['Domestic Connections'].value_counts()
# Out:
# Domestic Connections
# 151936     1
# 123314     1
# 366159     1
# 147718     1
# 108511     1
# 178574     1
# 249471     1
# 271284     1
# 224515     1
# 960744     1
# 135896     1
# 206547     1
# 422763     1
# 167496     1
# 363927     1
# 1047202    1
# 272987     1
# 175678     1
# 185999     1
# 257680     1
# 153923     1
# 101064     1
# 397024     1
# 309030     1
# 210720     1
# 92452      1
# 144768     1
# 148566     1
# 267097     1
# 1469633    1
# 191627     1
# Name: count, dtype: int64

# %%
dt.head()
# Out:
#    Districts  Domestic Connections  Industrial Connections  \
# 0   ADILABAD                151936                    1074
# 1  BHADRADRI                272987                    1396
# 2  HYDERABAD               1469633                   13041
# 3   JAGTIAL                 267097                    2132
# 4   JANGAON                 148566                    1536
#
#    Agriculture Connections  Commercial Connections  Other Connections
# 0                    17948                   14641               3302
# 1                    29951                   25990               5911
# 2                       86                  324781              18987
# 3                   113165                   23109               6499
# 4                    80002                   11366               4432

# %%
plt.figure(figsize = (15,7))
dt['Domestic Connections'].plot(kind = "bar")
plt.xlabel("Domestic Connections")
plt.title("A plot showing  Domestic Connections")
plt.show()

# %%
plt.figure(figsize = (15,7))
dt['Domestic Connections'].plot(kind = "bar")
plt.xlabel("Agriculture Connections")
plt.title("A plot showing  Agriculture Connections")
plt.show()

# %%
'''
import pandas as pd


# Your data
data = {
    'Location': ['ADILABAD', 'BHADRADRI', 'HYDERABAD', 'JAGTIAL', 'JANGAON'],
    'Domestic Connections': [151936, 272987, 1469633, 267097, 148566],
    'Industrial Connections': [1074, 1396, 13041, 2132, 1536],
    'Agriculture Connections': [17948, 29951, 86, 113165, 80002],
    'Commercial Connections': [14641, 25990, 324781, 23109, 11366],
    'Other Connections': [3302, 5911, 18987, 6499, 4432]
}

dt = pd.DataFrame(data)

# Set 'Location' column as index for easy plotting
dt.set_index('Location', inplace=True)

# Create subplots for each category
fig, axes = plt.subplots(nrows=len(dt), ncols=1, figsize=(8, 6*len(dt)))

for i, (idx, row) in enumerate(dt.iterrows()):
    row.plot(kind='bar', ax=axes[i], color='skyblue')
    axes[i].set_title(idx)
    axes[i].set_ylabel('Connections')
    axes[i].set_xlabel('')

plt.tight_layout()
plt.show()

'''
# Out:
# "\nimport pandas as pd\n\n\n# Your data\ndata = {\n    'Location': ['ADILABAD', 'BHADRADRI', 'HYDERABAD', 'JAGTIAL', 'JANGAON'],\n    'Domestic Connections': [151936, 272987, 1469633, 267097, 148566],\n    'Industrial Connections': [1074, 1396, 13041, 2132, 1536],\n    'Agriculture Connections': [17948, 29951, 86, 113165, 80002],\n    'Commercial Connections': [14641, 25990, 324781, 23109, 11366],\n    'Other Connections': [3302, 5911, 18987, 6499, 4432]\n}\n\ndt = pd.DataFrame(data)\n\n# Set 'Location' column as index for easy plotting\ndt.set_index('Location', inplace=True)\n\n# Create subplots for each category\nfig, axes = plt.subplots(nrows=len(dt), ncols=1, figsize=(8, 6*len(dt)))\n\nfor i, (idx, row) in enumerate(dt.iterrows()):\n    row.plot(kind='bar', ax=axes[i], color='skyblue')\n    axes[i].set_title(idx)\n    axes[i].set_ylabel('Connections')\n    axes[i].set_xlabel('')\n\nplt.tight_layout()\nplt.show()\n\n"

# %%
dt['Commercial Connections'].plot(kind = 'bar')
# Out:
# <Axes: >
