# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/insurance/insurance.csv

# %%
dff = pd.read_csv("/kaggle/input/insurance/insurance.csv")
dff.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dff.shape
# Out:
# (1337, 7)

# %%
dff.drop_duplicates().sum()
# Out:
# age                                                     52440
# sex                                                       274
# bmi                                                 40997.035
# children                                                 1465
# smoker      yesnonononononononononoyesnonoyesnonononoyesno...
# region      southwestsoutheastsoutheastnorthwestnorthwests...
# charges                                       17754185.427659
# dtype: object

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   int64
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 83.6+ KB

# %%
dff.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dff.describe().T
# Out:
#            count          mean           std        min       25%        50%  \
# age       1337.0     39.222139     14.044333    18.0000    27.000    39.0000
# sex       1337.0      0.204936      0.403806     0.0000     0.000     0.0000
# bmi       1337.0     30.663452      6.100468    15.9600    26.290    30.4000
# children  1337.0      1.095737      1.205571     0.0000     0.000     1.0000
# charges   1337.0  13279.121487  12110.359656  1121.8739  4746.344  9386.1613
#
#                   75%          max
# age          51.00000     64.00000
# sex           0.00000      1.00000
# bmi          34.70000     53.13000
# children      2.00000      5.00000
# charges   16657.71745  63770.42801

# %% [markdown]
# **Data Cleaning**

# %%
dff.drop_duplicates(inplace = True)
dff.drop_duplicates().sum()
# Out:
# age                                                     52440
# sex                                                       274
# bmi                                                 40997.035
# children                                                 1465
# smoker      yesnonononononononononoyesnonoyesnonononoyesno...
# region      southwestsoutheastsoutheastnorthwestnorthwests...
# charges                                       17754185.427659
# dtype: object

# %%
num = dff.select_dtypes(include = "number")
num
# Out:
#       age  sex     bmi  children      charges
# 0      19    1  27.900         0  16884.92400
# 1      18    0  33.770         1   1725.55230
# 2      28    0  33.000         3   4449.46200
# 3      33    0  22.705         0  21984.47061
# 4      32    0  28.880         0   3866.85520
# ...   ...  ...     ...       ...          ...
# 1333   50    0  30.970         3  10600.54830
# 1334   18    0  31.920         0   2205.98080
# 1335   18    0  36.850         0   1629.83350
# 1336   21    0  25.800         0   2007.94500
# 1337   61    1  29.070         0  29141.36030
#
# [1337 rows x 5 columns]

# %%
corel = num.corr()
corel
# Out:
#                age       sex       bmi  children   charges
# age       1.000000 -0.025587  0.109344  0.041536  0.298308
# sex      -0.025587  1.000000  0.003746  0.007331  0.787234
# bmi       0.109344  0.003746  1.000000  0.012755  0.198401
# children  0.041536  0.007331  0.012755  1.000000  0.067389
# charges   0.298308  0.787234  0.198401  0.067389  1.000000

# %%
sns.heatmap(corel, cmap='viridis', annot=True)
plt.show()

# %%
dff.describe(include = 'object').T
# Out:
#        count unique        top  freq
# smoker  1337      2         no  1063
# region  1337      4  southeast   364

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
dff['sex'] = le.fit_transform(dff['sex'])
dff.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
dff['sex'] = le.fit_transform(dff['smoker'])
dff.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    1  27.900         0    yes  southwest  16884.92400
# 1   18    0  33.770         1     no  southeast   1725.55230
# 2   28    0  33.000         3     no  southeast   4449.46200
# 3   33    0  22.705         0     no  northwest  21984.47061
# 4   32    0  28.880         0     no  northwest   3866.85520

# %%
dff1=pd.get_dummies(dff['region'], drop_first = True, prefix = 'region').astype(int)
dff1
# Out:
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [1337 rows x 3 columns]

# %%
dff.drop(['region'], axis=1, inplace=True)
dff2 = pd.concat([dff1, dff], axis = 1)
dff2
# Out:
#       region_northwest  region_southeast  region_southwest  age  sex     bmi  \
# 0                    0                 0                 1   19    1  27.900
# 1                    0                 1                 0   18    0  33.770
# 2                    0                 1                 0   28    0  33.000
# 3                    1                 0                 0   33    0  22.705
# 4                    1                 0                 0   32    0  28.880
# ...                ...               ...               ...  ...  ...     ...
# 1333                 1                 0                 0   50    0  30.970
# 1334                 0                 0                 0   18    0  31.920
# 1335                 0                 1                 0   18    0  36.850
# 1336                 0                 0                 1   21    0  25.800
# 1337                 1                 0                 0   61    1  29.070
#
#       children smoker      charges
# ...

# %%
#defining the dependent and independent variables

X = dff.drop(['charges'], axis = 1)

y = dff['charges']

X.head()
# Out:
#    age  sex     bmi  children smoker
# 0   19    1  27.900         0    yes
# 1   18    0  33.770         1     no
# 2   28    0  33.000         3     no
# 3   33    0  22.705         0     no
# 4   32    0  28.880         0     no

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print("shape of X_train: ", X_train.shape)
print('*' * 50)
print("shape of X_test: ", X_test.shape)
print('*' * 50)
print("shape of y_train: ", y_train.shape)
print('*' * 50)
print("shape of y_test: ", y_test.shape)
print('*' * 50)
# Out:
# shape of X_train:  (1069, 5)
# **************************************************
# shape of X_test:  (268, 5)
# **************************************************
# shape of y_train:  (1069,)
# **************************************************
# shape of y_test:  (268,)
# **************************************************

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
X_train_scaled = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)
X_train_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33/2983853459.py in ?()
#       1 scaler = StandardScaler()
#       2
# ----> 3 X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
#       4 X_train_scaled = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)
#       5 X_train_scaled.head()
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
# ...
